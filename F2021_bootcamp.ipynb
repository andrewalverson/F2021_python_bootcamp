# %% [markdown]
# Strings and numbers

# %% [markdown]
# Lists

# %% [markdown]
# Let's clone a GitHub repository to fetch tonight's data

# %%
# !git clone https://github.com/andrewalverson/F2021_python_bootcamp
